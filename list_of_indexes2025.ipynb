# %% [markdown]
# <a href="https://colab.research.google.com/github/higebobo/my-colab/blob/main/list_of_indexes2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 主要指数銘柄一覧(2025年版)

# %% [markdown]
# ## Import section

# %%
from io import StringIO
import subprocess
import tempfile
from typing import Any
import pandas as pd
import requests

# %% [markdown]
# ## 東証

# %% [markdown]
# ### 日経225

# %%
url = "https://site1.sbisec.co.jp/ETGate/?OutSide=on&_ControlID=WPLETmgR001Control&_PageID=WPLETmgR001Mdtl20&_DataStoreID=DSWPLETmgR001Control&_ActionID=DefaultAID&getFlg=on&burl=search_market&cat1=market&cat2=none&dir=info&file=market_meigara_225.html"
table_list: list = pd.read_html(url, encoding="cp932")
df: pd.DataFrame = table_list[1].iloc[:, [0, 1]]
df = df.drop(0)

df
# Out:
# /usr/local/lib/python3.12/dist-packages/bs4/__init__.py:341: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn(
#     銘柄コード           銘柄名
# 1    1332          ニッスイ
# 2    1605         INPEX
# 3    1721  コムシスホールディングス
# 4    1801          大成建設
# 5    1802           大林組
# ..    ...           ...
# 221  9735           セコム
# 222  9766       コナミグループ
# 223  9843   ニトリホールディングス
# 224  9983   ファーストリテイリング
# 225  9984    ソフトバンクグループ
#
# [225 rows x 2 columns]

# %% [markdown]
# ### JPX150

# %%
url = "https://www.jpx.co.jp/automation/markets/indices/jpx-prime150/files/jpxprime150weight_j.csv"
df = pd.read_csv(url, encoding="cp932")
df = df.iloc[1:-11, [2, 1]]
df[df.columns[0]] = df[df.columns[0]].astype(str).str[:4]

df
# Out:
#       コード               銘柄名称
# 1    1911               住友林業
# 2    1925            大和ハウス工業
# 3    1928              積水ハウス
# 4    2127  日本Ｍ＆Ａセンターホールディングス
# 5    2222             寿スピリッツ
# ..    ...                ...
# 143  9759                ＮＳＤ
# 144  9766            コナミグループ
# 145  9843        ニトリホールディングス
# 146  9983        ファーストリテイリング
# 147  9984         ソフトバンクグループ
#
# [147 rows x 2 columns]

# %% [markdown]
# ### JPX400

# %%
url = "https://indexes.nikkei.co.jp/nkave/archives/file/jpx_nikkei_index_400_weight_jp.csv"
response: Any = requests.get(url)
decoded_content: str = response.content.decode("cp932")
csv_data: str = StringIO(decoded_content)
df = pd.read_csv(csv_data).iloc[:-1, [2, 1]]
df[df.columns[0]] = df[df.columns[0]].astype(str).str[:4]

df
# Out:
#       コード             銘柄名
# 0    1332            ニッスイ
# 1    1414  ショーボンドホールディングス
# 2    1419           タマホーム
# 3    1518    三井松島ホールディングス
# 4    1605           ＩＮＰＥＸ
# ..    ...             ...
# 390  9766         コナミグループ
# 391  9843     ニトリホールディングス
# 392  9962       ミスミグループ本社
# 393  9983     ファーストリテイリング
# 394  9989          サンドラッグ
#
# [395 rows x 2 columns]

# %% [markdown]
# ### JPXから取得するデータ

# %%
url = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
df_jpx:pd.DataFrame = pd.read_excel(url)

# %% [markdown]
# ### 東証プライム

# %%
df = df_jpx.loc[df_jpx["市場・商品区分"].str.contains("プライム")].iloc[:, [1, 2]]
df
# Out:
#        コード              銘柄名
# 0     1301               極洋
# 18    1332             ニッスイ
# 19    1333           マルハニチロ
# 39    1375       ユキグニファクトリー
# 41    1377           サカタのタネ
# ...    ...              ...
# 4402  9987             スズケン
# 4403  9989           サンドラッグ
# 4404  9990  サックスバー　ホールディングス
# 4405  9991             ジェコス
# 4409  9997             ベルーナ
#
# [1619 rows x 2 columns]

# %% [markdown]
# ### 東証スタンダード

# %%
df = df_jpx.loc[df_jpx["市場・商品区分"].str.contains("スタンダード")].iloc[:, [1, 2]]
df
# Out:
#        コード     銘柄名
# 40    1376   カネコ種苗
# 44    1380    秋川牧園
# 45    1381   アクシーズ
# 46    1382     ホーブ
# 47    1383  ベルグアース
# ...    ...     ...
# 4398  9982   タキヒヨー
# 4401  9986    蔵王産業
# 4406  9993    ヤマザワ
# 4407  9994     やまや
# 4408  9996   サトー商会
#
# [1573 rows x 2 columns]

# %% [markdown]
# ### 東証グロース

# %%
df = df_jpx.loc[df_jpx["市場・商品区分"].str.contains("グロース")].iloc[:, [1, 2]]
df
# Out:
#        コード                 銘柄名
# 5     130A   Ｖｅｒｉｔａｓ　Ｉｎ　Ｓｉｌｉｃｏ
# 30    135A      ＶＲＡＩＮ　Ｓｏｌｕｔｉｏｎ
# 43    137A            Ｃｏｃｏｌｉｖｅ
# 49    138A            光フードサービス
# 54    1401              エムビーエス
# ...    ...                 ...
# 4233  9560              プログリット
# 4234  9561            グラッドキューブ
# 4235  9562             ビジネスコーチ
# 4236  9563  Ａｔｌａｓ　Ｔｅｃｈｎｏｌｏｇｉｅｓ
# 4238  9565                ＧＬＯＥ
#
# [608 rows x 2 columns]

# %% [markdown]
# ### TOPIX

# %%
df = df_jpx.loc[df_jpx["規模区分"].isin([
                                    "TOPIX Core30",
                                    "TOPIX Large70",
                                    "TOPIX Mid400",
                                    "TOPIX Small 1",
                                    "TOPIX Small 2",
                                ])].iloc[:, [1, 2]]
df
# Out:
#        コード              銘柄名
# 0     1301               極洋
# 18    1332             ニッスイ
# 19    1333           マルハニチロ
# 39    1375       ユキグニファクトリー
# 40    1376            カネコ種苗
# ...    ...              ...
# 4402  9987             スズケン
# 4403  9989           サンドラッグ
# 4404  9990  サックスバー　ホールディングス
# 4405  9991             ジェコス
# 4409  9997             ベルーナ
#
# [1680 rows x 2 columns]

# %% [markdown]
# ### TOPIX100

# %%
df = df_jpx.loc[df_jpx["規模区分"].isin([
                                    "TOPIX Core30",
                                    "TOPIX Large70",
                                ])].iloc[:, [1, 2]]
df
# Out:
#        コード              銘柄名
# 338   1925          大和ハウス工業
# 340   1928            積水ハウス
# 681   2502  アサヒグループホールディングス
# 682   2503      キリンホールディングス
# 864   2802              味の素
# ...    ...              ...
# 4182  9434           ソフトバンク
# 4299  9735              セコム
# 4342  9843      ニトリホールディングス
# 4399  9983      ファーストリテイリング
# 4400  9984       ソフトバンクグループ
#
# [100 rows x 2 columns]

# %% [markdown]
# ### TOPIX 500

# %%
df = df_jpx.loc[df_jpx["規模区分"].isin([
                                    "TOPIX Core30",
                                    "TOPIX Large70",
                                    "TOPIX Mid400",
                                ])].iloc[:, [1, 2]]
df
# Out:
#        コード             銘柄名
# 18    1332            ニッスイ
# 19    1333          マルハニチロ
# 57    1414  ショーボンドホールディングス
# 58    1417         ミライト・ワン
# 168   1605           ＩＮＰＥＸ
# ...    ...             ...
# 4389  9962       ミスミグループ本社
# 4399  9983     ファーストリテイリング
# 4400  9984      ソフトバンクグループ
# 4402  9987            スズケン
# 4403  9989          サンドラッグ
#
# [497 rows x 2 columns]

# %% [markdown]
# ### TOPIX1000

# %%
df = df_jpx.loc[df_jpx["規模区分"].isin([
                                    "TOPIX Core30",
                                    "TOPIX Large70",
                                    "TOPIX Mid400",
                                    "TOPIX Small 1",
                                ])].iloc[:, [1, 2]]
df
# Out:
#        コード             銘柄名
# 18    1332            ニッスイ
# 19    1333          マルハニチロ
# 41    1377          サカタのタネ
# 57    1414  ショーボンドホールディングス
# 58    1417         ミライト・ワン
# ...    ...             ...
# 4399  9983     ファーストリテイリング
# 4400  9984      ソフトバンクグループ
# 4402  9987            スズケン
# 4403  9989          サンドラッグ
# 4409  9997            ベルーナ
#
# [985 rows x 2 columns]

# %% [markdown]
# ### ダウ・ジョーンズ

# %%
"""
url = "https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average"
table_list: list = pd.read_html(url)
df: pd.DataFrame = table_list[2].iloc[:, [2, 0]]
"""
url = "https://www.180.co.jp/world_etf_adr/dow30/dow30.htm"
table_list: list = pd.read_html(url)
df: pd.DataFrame = table_list[0].iloc[1:-1, [0, 1]]
df.columns = ['ticker', 'name']
df['name'] = df['name'].str.split().str[1:].str.join(' ')
df
# Out:
#    ticker                                         name
# 1    AAPL                                   Apple Inc.
# 2    AMGN                                   Amgen Inc.
# 3    AMZN                             Amazon.com, Inc.
# 4     AXP                     American Express Company
# 5      BA                           The Boeing Company
# 6     CAT                             Caterpillar Inc.
# 7     CRM                             Salesforce, Inc.
# 8    CSCO                          Cisco Systems, Inc.
# 9     CVX                          Chevron Corporation
# 10    DIS                      The Walt Disney Company
# 11     GS                The Goldman Sachs Group, Inc.
# 12     HD                         The Home Depot, Inc.
# 13    HON                 Honeywell International Inc.
# 14    IBM  International Business Machines Corporation
# 15    JNJ                            Johnson & Johnson
# 16    JPM                         JPMorgan Chase & Co.
# ...

# %% [markdown]
# ### S&P500

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
cmd = ("curl", "-X", "GET", url)
result = subprocess.run(cmd, capture_output=True, text=True)
with tempfile.NamedTemporaryFile(suffix=".htm") as filename:
    with open(filename.name, "w") as f:
        f.write(result.stdout)
    table_list: list = pd.read_html(filename.name)
    df: pd.DataFrame = table_list[0].iloc[:, [0, 1]]

df
# Out:
#     Symbol             Security
# 0      MMM                   3M
# 1      AOS          A. O. Smith
# 2      ABT  Abbott Laboratories
# 3     ABBV               AbbVie
# 4      ACN            Accenture
# ..     ...                  ...
# 498    XYL           Xylem Inc.
# 499    YUM          Yum! Brands
# 500   ZBRA   Zebra Technologies
# 501    ZBH        Zimmer Biomet
# 502    ZTS               Zoetis
#
# [503 rows x 2 columns]

# %% [markdown]
# ### NASDAQ100

# %%
"""
url = "https://go.sbisec.co.jp/prd/fund/ifree_nasdaq100/brand/"
table_list: list = pd.read_html(url)
df = table_list[0]
"""
url = "https://en.wikipedia.org/wiki/NASDAQ-100"
cmd = ("curl", "-X", "GET", url)
result = subprocess.run(cmd, capture_output=True, text=True)
with tempfile.NamedTemporaryFile(suffix=".htm") as filename:
    with open(filename.name, "w") as f:
        f.write(result.stdout)
    table_list: list = pd.read_html(filename.name)
    df: pd.DataFrame = table_list[4].iloc[:, [0, 1]]

df
# Out:
#     Ticker                  Company
# 0     ADBE               Adobe Inc.
# 1      AMD   Advanced Micro Devices
# 2     ABNB                   Airbnb
# 3    GOOGL  Alphabet Inc. (Class A)
# 4     GOOG  Alphabet Inc. (Class C)
# ..     ...                      ...
# 96    VRTX   Vertex Pharmaceuticals
# 97     WBD   Warner Bros. Discovery
# 98    WDAY            Workday, Inc.
# 99     XEL              Xcel Energy
# 100     ZS                  Zscaler
#
# [101 rows x 2 columns]
